# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import csv
import re
from mtgsdk import Set
from mtgsdk import Card

# %%
sets = Set.all()

with open('dataSet/allSets.csv', 'w', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['name', 'code', 'mkm_id', 'mkm_name', 'release_date'])
    for set in sets:
        writer.writerow([set.name, set.code, set.mkm_id, set.mkm_name, set.release_date])

# %% [markdown]
# This will create a file with all cards of each set

# %%
with open('dataSet/allSets.csv', 'r', encoding='utf-8') as setsFile:
    reader = csv.DictReader(setsFile)
    totalRows = sum(1 for row in reader)
    setsFile.seek(0)
    downloadedRows = 0
    for row in reader:
        cards = Card.where(set= row['code']).all()    
        filename = re.sub(r'[\\/:"*?<>|]+', '', row['name'])
        with open('dataSet/sets/'+filename+ '.csv', 'w', encoding='utf-8') as exSetFile:
            writerCard = csv.writer(exSetFile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
            writerCard.writerow(['name','multiverse_id','layout','names','mana_cost','cmc','colors',
                                 'color_identity','type','supertypes','subtypes','rarity','text','flavor',
                                 'artist','number','power','toughness','loyalty','variations','watermark','border',
                                 'timeshifted','hand','life','reserved','release_date','starter','rulings','foreign_names',
                                 'printings','original_text','original_type','legalities','source','image_url',
                                 'set','set_name','id'])
            for card in cards:
                writerCard.writerow([card.name,card.multiverse_id,card.layout,card.names,card.mana_cost,card.cmc,card.colors,
                                     card.color_identity,card.type,card.supertypes,card.subtypes,card.rarity,card.text,card.flavor,
                                     card.artist,card.number,card.power,card.toughness,card.loyalty,card.variations,card.watermark,card.border,
                                     card.timeshifted,card.hand,card.life,card.release_date,card.starter,card.rulings,card.foreign_names,
                                     card.printings,card.original_text,card.original_type,card.legalities,card.source,card.image_url,
                                     card.set,card.set_name,card.id])
        
        downloadedRows = downloadedRows + 1
        print('Downloaded '+ str(downloadedRows) + ' from ' + str(totalRows) + ' total sets')
# Out:
# Downloaded 1 from 230 total sets
# Downloaded 2 from 230 total sets
# Downloaded 3 from 230 total sets
# Downloaded 4 from 230 total sets
# Downloaded 5 from 230 total sets
# Downloaded 6 from 230 total sets
# Downloaded 7 from 230 total sets
# Downloaded 8 from 230 total sets
# Downloaded 9 from 230 total sets
# Downloaded 10 from 230 total sets
# Downloaded 11 from 230 total sets
# Downloaded 12 from 230 total sets
# Downloaded 13 from 230 total sets
# Downloaded 14 from 230 total sets
# Downloaded 15 from 230 total sets
# Downloaded 16 from 230 total sets
# Downloaded 17 from 230 total sets
# Downloaded 18 from 230 total sets
# Downloaded 19 from 230 total sets
# Downloaded 20 from 230 total sets
# Downloaded 21 from 230 total sets
# Downloaded 22 from 230 total sets
# Downloaded 23 from 230 total sets
# Downloaded 24 from 230 total sets
# Downloaded 25 from 230 total sets
# Downloaded 26 from 230 total sets
# Downloaded 27 from 230 total sets
# Downloaded 28 from 230 total sets
# Downloaded 29 from 230 total sets
# Downloaded 30 from 230 total sets
# Downloaded 31 from 230 total sets
# Downloaded 32 from 230 total sets
# Downloaded 33 from 230 total sets
# Downloaded 34 from 230 total sets
# Downloaded 35 from 230 total sets
# Downloaded 36 from 230 total sets
# Downloaded 37 from 230 total sets
# Downloaded 38 from 230 total sets
# Downloaded 39 from 230 total sets
# Downloaded 40 from 230 total sets
# Downloaded 41 from 230 total sets
# Downloaded 42 from 230 total sets
# Downloaded 43 from 230 total sets
# Downloaded 44 from 230 total sets
# Downloaded 45 from 230 total sets
# Downloaded 46 from 230 total sets
# Downloaded 47 from 230 total sets
# Downloaded 48 from 230 total sets
# Downloaded 49 from 230 total sets
# Downloaded 50 from 230 total sets
# Downloaded 51 from 230 total sets
# Downloaded 52 from 230 total sets
# Downloaded 53 from 230 total sets
# Downloaded 54 from 230 total sets
# Downloaded 55 from 230 total sets
# Downloaded 56 from 230 total sets
# Downloaded 57 from 230 total sets
# Downloaded 58 from 230 total sets
# Downloaded 59 from 230 total sets
# Downloaded 60 from 230 total sets
# Downloaded 61 from 230 total sets
# Downloaded 62 from 230 total sets
# Downloaded 63 from 230 total sets
# Downloaded 64 from 230 total sets
# Downloaded 65 from 230 total sets
# Downloaded 66 from 230 total sets
# Downloaded 67 from 230 total sets
# Downloaded 68 from 230 total sets
# Downloaded 69 from 230 total sets
# Downloaded 70 from 230 total sets
# Downloaded 71 from 230 total sets
# Downloaded 72 from 230 total sets
# Downloaded 73 from 230 total sets
# Downloaded 74 from 230 total sets
# Downloaded 75 from 230 total sets
# Downloaded 76 from 230 total sets
# Downloaded 77 from 230 total sets
# Downloaded 78 from 230 total sets
# Downloaded 79 from 230 total sets
# Downloaded 80 from 230 total sets
# Downloaded 81 from 230 total sets
# Downloaded 82 from 230 total sets
# Downloaded 83 from 230 total sets
# Downloaded 84 from 230 total sets
# Downloaded 85 from 230 total sets
# Downloaded 86 from 230 total sets
# Downloaded 87 from 230 total sets
# Downloaded 88 from 230 total sets
# Downloaded 89 from 230 total sets
# Downloaded 90 from 230 total sets
# Downloaded 91 from 230 total sets
# Downloaded 92 from 230 total sets
# Downloaded 93 from 230 total sets
# Downloaded 94 from 230 total sets
# Downloaded 95 from 230 total sets
# Downloaded 96 from 230 total sets
# Downloaded 97 from 230 total sets
# Downloaded 98 from 230 total sets
# Downloaded 99 from 230 total sets
# Downloaded 100 from 230 total sets
# Downloaded 101 from 230 total sets
# Downloaded 102 from 230 total sets
# Downloaded 103 from 230 total sets
# Downloaded 104 from 230 total sets
# Downloaded 105 from 230 total sets
# Downloaded 106 from 230 total sets
# Downloaded 107 from 230 total sets
# Downloaded 108 from 230 total sets
# Downloaded 109 from 230 total sets
# Downloaded 110 from 230 total sets
# Downloaded 111 from 230 total sets
# Downloaded 112 from 230 total sets
# Downloaded 113 from 230 total sets
# Downloaded 114 from 230 total sets
# Downloaded 115 from 230 total sets
# Downloaded 116 from 230 total sets
# Downloaded 117 from 230 total sets
# Downloaded 118 from 230 total sets
# Downloaded 119 from 230 total sets
# Downloaded 120 from 230 total sets
# Downloaded 121 from 230 total sets
# Downloaded 122 from 230 total sets
# Downloaded 123 from 230 total sets
# Downloaded 124 from 230 total sets
# Downloaded 125 from 230 total sets
# Downloaded 126 from 230 total sets
# Downloaded 127 from 230 total sets
# Downloaded 128 from 230 total sets
# Downloaded 129 from 230 total sets
# Downloaded 130 from 230 total sets
# Downloaded 131 from 230 total sets
# Downloaded 132 from 230 total sets
# Downloaded 133 from 230 total sets
# Downloaded 134 from 230 total sets
# Downloaded 135 from 230 total sets
# Downloaded 136 from 230 total sets
# Downloaded 137 from 230 total sets
# Downloaded 138 from 230 total sets
# Downloaded 139 from 230 total sets
# Downloaded 140 from 230 total sets
# Downloaded 141 from 230 total sets
# Downloaded 142 from 230 total sets
# Downloaded 143 from 230 total sets
# Downloaded 144 from 230 total sets
# Downloaded 145 from 230 total sets
# Downloaded 146 from 230 total sets
# Downloaded 147 from 230 total sets
# Downloaded 148 from 230 total sets
# Downloaded 149 from 230 total sets
# Downloaded 150 from 230 total sets
# Downloaded 151 from 230 total sets
# Downloaded 152 from 230 total sets
# Downloaded 153 from 230 total sets
# Downloaded 154 from 230 total sets
# Downloaded 155 from 230 total sets
# Downloaded 156 from 230 total sets
# Downloaded 157 from 230 total sets
# Downloaded 158 from 230 total sets
# Downloaded 159 from 230 total sets
# Downloaded 160 from 230 total sets
# Downloaded 161 from 230 total sets
# Downloaded 162 from 230 total sets
# Downloaded 163 from 230 total sets
# Downloaded 164 from 230 total sets
# Downloaded 165 from 230 total sets
# Downloaded 166 from 230 total sets
# Downloaded 167 from 230 total sets
# Downloaded 168 from 230 total sets
# Downloaded 169 from 230 total sets
# Downloaded 170 from 230 total sets
# Downloaded 171 from 230 total sets
# Downloaded 172 from 230 total sets
# Downloaded 173 from 230 total sets
# Downloaded 174 from 230 total sets
# Downloaded 175 from 230 total sets
# Downloaded 176 from 230 total sets
# Downloaded 177 from 230 total sets
# Downloaded 178 from 230 total sets
# Downloaded 179 from 230 total sets
# Downloaded 180 from 230 total sets
# Downloaded 181 from 230 total sets
# Downloaded 182 from 230 total sets
# Downloaded 183 from 230 total sets
# Downloaded 184 from 230 total sets
# Downloaded 185 from 230 total sets
# Downloaded 186 from 230 total sets
# Downloaded 187 from 230 total sets
# Downloaded 188 from 230 total sets
# Downloaded 189 from 230 total sets
# Downloaded 190 from 230 total sets
# Downloaded 191 from 230 total sets
# Downloaded 192 from 230 total sets
# Downloaded 193 from 230 total sets
# Downloaded 194 from 230 total sets
# Downloaded 195 from 230 total sets
# Downloaded 196 from 230 total sets
# Downloaded 197 from 230 total sets
# Downloaded 198 from 230 total sets
# Downloaded 199 from 230 total sets
# Downloaded 200 from 230 total sets
# Downloaded 201 from 230 total sets
# Downloaded 202 from 230 total sets
# Downloaded 203 from 230 total sets
# Downloaded 204 from 230 total sets
# Downloaded 205 from 230 total sets
# Downloaded 206 from 230 total sets
# Downloaded 207 from 230 total sets
# Downloaded 208 from 230 total sets
# Downloaded 209 from 230 total sets
# Downloaded 210 from 230 total sets
# Downloaded 211 from 230 total sets
# Downloaded 212 from 230 total sets
# Downloaded 213 from 230 total sets
# Downloaded 214 from 230 total sets
# Downloaded 215 from 230 total sets
# Downloaded 216 from 230 total sets
# Downloaded 217 from 230 total sets
# Downloaded 218 from 230 total sets
# Downloaded 219 from 230 total sets
# Downloaded 220 from 230 total sets
# Downloaded 221 from 230 total sets
# Downloaded 222 from 230 total sets
# Downloaded 223 from 230 total sets
# Downloaded 224 from 230 total sets
# Downloaded 225 from 230 total sets
# Downloaded 226 from 230 total sets
# Downloaded 227 from 230 total sets
# Downloaded 228 from 230 total sets
# Downloaded 229 from 230 total sets
# Downloaded 230 from 230 total sets
# Downloaded 231 from 230 total sets
