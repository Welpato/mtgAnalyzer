# %%
#This class is used to download all the sets and cards information
import src.downloadProcess as dMtgInfo
#This class has all the analytical functions
import src.mtgBaseClass as mbc
import src.cardSet as cs

# %% [markdown]
# Before start using the analitycal class you need to run the next cell to donwload all the Sets information

# %%
downloadClass = dMtgInfo.downloadMtgInfo()

#Downloading the set list
downloadClass.downloadSets()

#Downloading all the cards of each set
downloadClass.downloadCards()

# %%
#In this array you can insert all the sets that you want to check
setList = ['Guilds of Ravnica']
compare = mbc.mtgBase(setList)

# %%
#Plot the total of cards of each set
compare.plotCardsTotal()

# %%
#Plot the median CMC per rarity of each set
compare.plotMedianCmc()

# %%
compare.plotCardsWithColorIdentity("['W']")
# Out:
# Guilds of Ravnica
#                      name  multiverse_id  layout names  mana_cost  cmc  \
# 0        Blade Instructor         452751  normal   NaN     {2}{W}    3
# 1            Bounty Agent         452752  normal   NaN     {1}{W}    2
# 2       Candlelight Vigil         452753  normal   NaN     {3}{W}    4
# 3           Citywide Bust         452754  normal   NaN  {1}{W}{W}    3
# 4      Collar the Culprit         452755  normal   NaN     {3}{W}    4
# 5       Conclave Tribunal         452756  normal   NaN     {3}{W}    4
# 6        Crush Contraband         452757  normal   NaN     {3}{W}    4
# 7            Dawn of Hope         452758  normal   NaN     {1}{W}    2
# 8                Demotion         452759  normal   NaN        {W}    1
# 9       Divine Visitation         452760  normal   NaN  {3}{W}{W}    5
# 10    Flight of Equenauts         452761  normal   NaN     {7}{W}    8
# 11        Gird for Battle         452762  normal   NaN        {W}    1
# 12         Haazda Marshal         452763  normal   NaN        {W}    1
# 13          Healer's Hawk         452764  normal   NaN        {W}    1
# 14         Hunted Witness         452765  normal   NaN        {W}    1
# 15      Inspiring Unicorn         452766  normal   NaN  {2}{W}{W}    4
# 16    Intrusive Packbeast         452767  normal   NaN     {4}{W}    5
# 17         Ledev Guardian         452768  normal   NaN     {3}{W}    4
# 18    Light of the Legion         452769  normal   NaN  {4}{W}{W}    6
# 19       Loxodon Restorer         452770  normal   NaN  {4}{W}{W}    6
# 20         Luminous Bonds         452771  normal   NaN     {2}{W}    3
# 21       Parhelion Patrol         452772  normal   NaN     {3}{W}    4
# 22         Righteous Blow         452773  normal   NaN        {W}    1
# 23            Roc Charger         452774  normal   NaN     {2}{W}    3
# 24          Skyline Scout         452775  normal   NaN     {1}{W}    2
# 25       Sunhome Stalwart         452776  normal   NaN     {1}{W}    2
# 26       Sworn Companions         452777  normal   NaN     {2}{W}    3
# 27             Take Heart         452778  normal   NaN        {W}    1
# 28   Tenth District Guard         452779  normal   NaN     {1}{W}    2
# 29      Venerated Loxodon         452780  normal   NaN     {4}{W}    5
# 269                Plains         455600  normal   NaN        NaN    0
#
#         colors color_identity                        type supertypes  \
# 0    ['White']          ['W']    Creature — Human Soldier        NaN
# 1    ['White']          ['W']    Creature — Human Soldier        NaN
# 2    ['White']          ['W']          Enchantment — Aura        NaN
# 3    ['White']          ['W']                     Sorcery        NaN
# 4    ['White']          ['W']                     Instant        NaN
# 5    ['White']          ['W']                 Enchantment        NaN
# 6    ['White']          ['W']                     Instant        NaN
# 7    ['White']          ['W']                 Enchantment        NaN
# 8    ['White']          ['W']          Enchantment — Aura        NaN
# 9    ['White']          ['W']                 Enchantment        NaN
# 10   ['White']          ['W']     Creature — Human Knight        NaN
# 11   ['White']          ['W']                     Sorcery        NaN
# 12   ['White']          ['W']    Creature — Human Soldier        NaN
# 13   ['White']          ['W']             Creature — Bird        NaN
# 14   ['White']          ['W']            Creature — Human        NaN
# 15   ['White']          ['W']          Creature — Unicorn        NaN
# 16   ['White']          ['W']            Creature — Beast        NaN
# 17   ['White']          ['W']     Creature — Human Knight        NaN
# 18   ['White']          ['W']            Creature — Angel        NaN
# 19   ['White']          ['W']  Creature — Elephant Cleric        NaN
# 20   ['White']          ['W']          Enchantment — Aura        NaN
# 21   ['White']          ['W']     Creature — Human Knight        NaN
# 22   ['White']          ['W']                     Instant        NaN
# 23   ['White']          ['W']             Creature — Bird        NaN
# 24   ['White']          ['W']      Creature — Human Scout        NaN
# 25   ['White']          ['W']    Creature — Human Soldier        NaN
# 26   ['White']          ['W']                     Sorcery        NaN
# 27   ['White']          ['W']                     Instant        NaN
# 28   ['White']          ['W']    Creature — Human Soldier        NaN
# 29   ['White']          ['W']  Creature — Elephant Cleric        NaN
# 269        NaN          ['W']         Basic Land — Plains  ['Basic']
#
#                    subtypes       rarity  \
# 0      ['Human', 'Soldier']       Common
# 1      ['Human', 'Soldier']         Rare
# 2                  ['Aura']       Common
# 3                       NaN         Rare
# 4                       NaN       Common
# 5                       NaN     Uncommon
# 6                       NaN     Uncommon
# 7                       NaN         Rare
# 8                  ['Aura']     Uncommon
# 9                       NaN  Mythic Rare
# 10      ['Human', 'Knight']     Uncommon
# 11                      NaN     Uncommon
# 12     ['Human', 'Soldier']     Uncommon
# 13                 ['Bird']       Common
# 14                ['Human']       Common
# 15              ['Unicorn']     Uncommon
# 16                ['Beast']       Common
# 17      ['Human', 'Knight']       Common
# 18                ['Angel']         Rare
# 19   ['Elephant', 'Cleric']       Common
# 20                 ['Aura']       Common
# 21      ['Human', 'Knight']       Common
# 22                      NaN       Common
# 23                 ['Bird']     Uncommon
# 24       ['Human', 'Scout']       Common
# 25     ['Human', 'Soldier']     Uncommon
# 26                      NaN       Common
# 27                      NaN       Common
# 28     ['Human', 'Soldier']       Common
# 29   ['Elephant', 'Cleric']         Rare
# 269              ['Plains']   Basic Land
#
#                                                   text  \
# 0    Mentor (Whenever this creature attacks, put a ...
# 1    Vigilance\r\n{T}, Sacrifice Bounty Agent: Dest...
# 2    Enchant creature\r\nEnchanted creature gets +3...
# 3    Destroy all creatures with toughness 4 or grea...
# 4    Destroy target creature with toughness 4 or gr...
# 5    Convoke (Your creatures can help cast this spe...
# 6    Choose one or both —\r\n• Exile target artifac...
# 7    Whenever you gain life, you may pay {2}. If yo...
# 8    Enchant creature\r\nEnchanted creature can't b...
# 9    If one or more creature tokens would be create...
# 10   Convoke (Your creatures can help cast this spe...
# 11   Put a +1/+1 counter on each of up to two targe...
# 12   Whenever Haazda Marshal and at least two other...
# 13                                    Flying, lifelink
# 14   When Hunted Witness dies, create a 1/1 white S...
# 15   Whenever Inspiring Unicorn attacks, creatures ...
# 16   Vigilance\r\nWhen Intrusive Packbeast enters t...
# 17   Convoke (Your creatures can help cast this spe...
# 18   Flying\r\nMentor (Whenever this creature attac...
# 19   Convoke (Your creatures can help cast this spe...
# 20   Enchant creature\r\nEnchanted creature can't a...
# 21   Flying, vigilance\r\nMentor (Whenever this cre...
# 22   Righteous Blow deals 2 damage to target attack...
# 23   Flying\r\nWhenever Roc Charger attacks, target...
# 24   Whenever Skyline Scout attacks, you may pay {1...
# 25   First strike\r\nMentor (Whenever this creature...
# 26   Create two 1/1 white Soldier creature tokens w...
# 27   Target creature gets +2/+2 until end of turn. ...
# 28   When Tenth District Guard enters the battlefie...
# 29   Convoke (Your creatures can help cast this spe...
# 269                                                NaN
#
#                                                 flavor                artist  \
# 0    "Watch carefully. The gap between death and vi...          Zoltan Boros
# 1    "Lately I've seen the biggest bounties of my c...          Randy Vargas
# 2    Selesnya guildmages do not sleep so the rest o...   Alexander Forssberg
# 3    "Oh, you fellas are going to love the lockup. ...  Victor Adame Minguez
# 4    "Reports of Gruul rioters in four districts. S...  Victor Adame Minguez
# 5                                                  NaN          Seb McKinnon
# 6    The Izzet mage knew she would neither get her ...        Jason A. Engle
# 7    "To wage war, secure peace within yourself."\r...             Sung Choi
# 8    There's no greater honor than joining your cho...           Joe Slucher
# 9    The angels appreciated the offer but politely ...  Victor Adame Minguez
# 10   "Yes, there's competition between our equenaut...           Zezhou Chen
# 11   "You won't need the sword drills, your shields...          Jakub Kasper
# 12   Ravnica's convoluted power structure often boi...             Josh Hass
# 13   The wounded see the glow of its vials long bef...         Milivoj Ćeran
# 14   He ferried weapons, spells, exotic animals—but...         David Palumbo
# 15   There are two lives: the life you live before ...         Even Amundsen
# 16   Good at carrying things. Really good at knocki...           Jason Felix
# 17   "I've raised her since she was a pup, and she'...   Kimonas Theodossiou
# 18                                                 NaN          Alex Konstad
# 19                                                 NaN       Svetlin Velinov
# 20   "Article 5.8.2. Ensure proper restraint of any...             Mark Behm
# 21   "Too many have disappeared in these dark days....         Even Amundsen
# 22   "The Golgari believe they should be given what...                  Izzy
# 23   Rocs' innate fearlessness makes them ideal mou...          Titus Lunter
# 24   "Sometimes an angel passes by and gives me a l...    Paul Scott Canavan
# 25   "Before I let you wield one of these, let's se...          Matt Stewart
# 26   "The trouble with youths these days is that, i...       Jason Rainville
# 27   In the quiet before a battle, Boros soldiers w...        Lucas Graciano
# 28   "The Tenth has always been my home. This city ...      Craig J Spearing
# 29                                                 NaN           Zack Stella
# 269                                                NaN        Richard Wright
#
#     number power  toughness  loyalty  variations watermark  border  \
# 0        1     3        1.0      NaN         NaN     Boros     NaN
# 1        2     2        2.0      NaN         NaN       NaN     NaN
# 2        3   NaN        NaN      NaN         NaN       NaN     NaN
# 3        4   NaN        NaN      NaN         NaN       NaN     NaN
# 4        5   NaN        NaN      NaN         NaN       NaN     NaN
# 5        6   NaN        NaN      NaN         NaN  Selesnya     NaN
# 6        7   NaN        NaN      NaN         NaN       NaN     NaN
# 7        8   NaN        NaN      NaN         NaN       NaN     NaN
# 8        9   NaN        NaN      NaN         NaN       NaN     NaN
# 9       10   NaN        NaN      NaN         NaN       NaN     NaN
# 10      11     4        5.0      NaN         NaN  Selesnya     NaN
# 11      12   NaN        NaN      NaN         NaN       NaN     NaN
# 12      13     1        1.0      NaN         NaN       NaN     NaN
# 13      14     1        1.0      NaN         NaN       NaN     NaN
# 14      15     1        1.0      NaN         NaN       NaN     NaN
# 15      16     2        2.0      NaN         NaN       NaN     NaN
# 16      17     3        3.0      NaN         NaN       NaN     NaN
# 17      18     2        4.0      NaN         NaN  Selesnya     NaN
# 18      19     5        5.0      NaN         NaN     Boros     NaN
# 19      20     3        4.0      NaN         NaN  Selesnya     NaN
# 20      21   NaN        NaN      NaN         NaN       NaN     NaN
# 21      22     2        3.0      NaN         NaN     Boros     NaN
# 22      23   NaN        NaN      NaN         NaN       NaN     NaN
# 23      24     1        3.0      NaN         NaN       NaN     NaN
# 24      25     2        1.0      NaN         NaN       NaN     NaN
# 25      26     2        2.0      NaN         NaN     Boros     NaN
# 26      27   NaN        NaN      NaN         NaN       NaN     NaN
# 27      28   NaN        NaN      NaN         NaN       NaN     NaN
# 28      29     2        2.0      NaN         NaN       NaN     NaN
# 29      30     4        4.0      NaN         NaN  Selesnya     NaN
# 269    260   NaN        NaN      NaN         NaN     White     NaN
#
#      timeshifted  hand  life  reserved  release_date  \
# 0            NaN   NaN   NaN       NaN           NaN
# 1            NaN   NaN   NaN       NaN           NaN
# 2            NaN   NaN   NaN       NaN           NaN
# 3            NaN   NaN   NaN       NaN           NaN
# 4            NaN   NaN   NaN       NaN           NaN
# 5            NaN   NaN   NaN       NaN           NaN
# 6            NaN   NaN   NaN       NaN           NaN
# 7            NaN   NaN   NaN       NaN           NaN
# 8            NaN   NaN   NaN       NaN           NaN
# 9            NaN   NaN   NaN       NaN           NaN
# 10           NaN   NaN   NaN       NaN           NaN
# 11           NaN   NaN   NaN       NaN           NaN
# 12           NaN   NaN   NaN       NaN           NaN
# 13           NaN   NaN   NaN       NaN           NaN
# 14           NaN   NaN   NaN       NaN           NaN
# 15           NaN   NaN   NaN       NaN           NaN
# 16           NaN   NaN   NaN       NaN           NaN
# 17           NaN   NaN   NaN       NaN           NaN
# 18           NaN   NaN   NaN       NaN           NaN
# 19           NaN   NaN   NaN       NaN           NaN
# 20           NaN   NaN   NaN       NaN           NaN
# 21           NaN   NaN   NaN       NaN           NaN
# 22           NaN   NaN   NaN       NaN           NaN
# 23           NaN   NaN   NaN       NaN           NaN
# 24           NaN   NaN   NaN       NaN           NaN
# 25           NaN   NaN   NaN       NaN           NaN
# 26           NaN   NaN   NaN       NaN           NaN
# 27           NaN   NaN   NaN       NaN           NaN
# 28           NaN   NaN   NaN       NaN           NaN
# 29           NaN   NaN   NaN       NaN           NaN
# 269          NaN   NaN   NaN       NaN           NaN
#
#                                                starter  \
# 0    [{'text': "Mentor compares the power of the cr...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5    [{'text': "If Conclave Tribunal leaves the bat...
# 6    [{'text': "If you've chosen both modes and one...
# 7    [{'text': "Dawn of Hope's first ability trigge...
# 8    [{'text': 'Activated abilities contain a colon...
# 9    [{'text': 'The token\'s characteristics are en...
# 10   [{'text': "You can tap an untapped creature yo...
# 11   [{'text': "You can't target the same creature ...
# 12   [{'text': "Once Haazda Marshal's ability has t...
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17   [{'text': "You can tap an untapped creature yo...
# 18   [{'text': "If another white creature you contr...
# 19   [{'text': "You can tap an untapped creature yo...
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25   [{'text': "Mentor compares the power of the cr...
# 26                                                 NaN
# 27   [{'text': "You can cast Take Heart even if you...
# 28                                                 NaN
# 29   [{'text': "You can't tap more creatures to con...
# 269                                                NaN
#
#                                                rulings  \
# 0    [{'name': 'Klingen-Ausbilderin', 'imageUrl': '...
# 1    [{'name': 'Kopfgeld-Agentin', 'imageUrl': 'htt...
# 2    [{'name': 'Wache bei Kerzenschein', 'imageUrl'...
# 3    [{'name': 'Stadtweite Razzia', 'imageUrl': 'ht...
# 4    [{'name': 'Festnahme des Schuldigen', 'imageUr...
# 5    [{'name': 'Tribunal des Konklaves', 'imageUrl'...
# 6    [{'name': 'Zerstörung der Hehlerware', 'imageU...
# 7    [{'name': 'Hoffnungsschimmer', 'imageUrl': 'ht...
# 8    [{'name': 'Degradierung', 'imageUrl': 'http://...
# 9    [{'name': 'Göttliche Erscheinung', 'imageUrl':...
# 10   [{'name': 'Schar der Equinauten', 'imageUrl': ...
# 11   [{'name': 'Für den Kampf rüsten', 'imageUrl': ...
# 12   [{'name': 'Haazda-Marschall', 'imageUrl': 'htt...
# 13   [{'name': 'Falke des Heilers', 'imageUrl': 'ht...
# 14   [{'name': 'Verfolgter Zeuge', 'imageUrl': 'htt...
# 15   [{'name': 'Inspirierendes Einhorn', 'imageUrl'...
# 16   [{'name': 'Aufdringliche Packbestie', 'imageUr...
# 17   [{'name': 'Ledev-Wächterin', 'imageUrl': 'http...
# 18   [{'name': 'Licht der Legion', 'imageUrl': 'htt...
# 19   [{'name': 'Loxodon-Wiederhersteller', 'imageUr...
# 20   [{'name': 'Leuchtende Fesseln', 'imageUrl': 'h...
# 21   [{'name': 'Parhelion-Patrouille', 'imageUrl': ...
# 22   [{'name': 'Rechtschaffener Schlag', 'imageUrl'...
# 23   [{'name': 'Streit-Roc', 'imageUrl': 'http://ga...
# 24   [{'name': 'Häuserschluchtenspäher', 'imageUrl'...
# 25   [{'name': 'Sonnenheim-Getreuer', 'imageUrl': '...
# 26   [{'name': 'Treue Verbündete', 'imageUrl': 'htt...
# 27   [{'name': 'Ein Herz fassen', 'imageUrl': 'http...
# 28   [{'name': 'Wache des zehnten Distrikts', 'imag...
# 29   [{'name': 'Verehrtes Loxodon', 'imageUrl': 'ht...
# 269  [{'name': 'Ebene', 'imageUrl': 'http://gathere...
#
#                                          foreign_names  \
# 0                                              ['GRN']
# 1                                              ['GRN']
# 2                                              ['GRN']
# 3                                              ['GRN']
# 4                                              ['GRN']
# 5                                              ['GRN']
# 6                                              ['GRN']
# 7                                              ['GRN']
# 8                                              ['GRN']
# 9                                              ['GRN']
# 10                                             ['GRN']
# 11                                             ['GRN']
# 12                                             ['GRN']
# 13                                             ['GRN']
# 14                                             ['GRN']
# 15                                             ['GRN']
# 16                                             ['GRN']
# 17                                             ['GRN']
# 18                                             ['GRN']
# 19                                             ['GRN']
# 20                               ['RIX', 'M19', 'GRN']
# 21                                             ['GRN']
# 22                                      ['AVR', 'GRN']
# 23                                             ['GRN']
# 24                                             ['GRN']
# 25                                             ['GRN']
# 26                                             ['GRN']
# 27                                             ['GRN']
# 28                                             ['GRN']
# 29                                             ['GRN']
# 269  ['LEA', 'LEB', '2ED', 'CED', 'CEI', '3ED', '4E...
#
#                                              printings  \
# 0    Mentor <i>(Whenever this creature attacks, put...
# 1    Vigilance\r\n{T}, Sacrifice Bounty Agent: Dest...
# 2    Enchant creature\r\nEnchanted creature gets +3...
# 3    Destroy all creatures with toughness 4 or grea...
# 4    Destroy target creature with toughness 4 or gr...
# 5    Convoke <i>(Your creatures can help cast this ...
# 6    Choose one or both —\r\n• Exile target artifac...
# 7    Whenever you gain life, you may pay {2}. If yo...
# 8    Enchant creature\r\nEnchanted creature can't b...
# 9    If one or more creature tokens would be create...
# 10   Convoke <i>(Your creatures can help cast this ...
# 11   Put a +1/+1 counter on each of up to two targe...
# 12   Whenever Haazda Marshal and at least two other...
# 13                                    Flying, lifelink
# 14   When Hunted Witness dies, create a 1/1 white S...
# 15   Whenever Inspiring Unicorn attacks, creatures ...
# 16   Vigilance\r\nWhen Intrusive Packbeast enters t...
# 17   Convoke <i>(Your creatures can help cast this ...
# 18   Flying\r\nMentor <i>(Whenever this creature at...
# 19   Convoke <i>(Your creatures can help cast this ...
# 20   Enchant creature\r\nEnchanted creature can't a...
# 21   Flying, vigilance\r\nMentor <i>(Whenever this ...
# 22   Righteous Blow deals 2 damage to target attack...
# 23   Flying\r\nWhenever Roc Charger attacks, target...
# 24   Whenever Skyline Scout attacks, you may pay {1...
# 25   First strike\r\nMentor <i>(Whenever this creat...
# 26   Create two 1/1 white Soldier creature tokens w...
# 27   Target creature gets +2/+2 until end of turn. ...
# 28   When Tenth District Guard enters the battlefie...
# 29   Convoke <i>(Your creatures can help cast this ...
# 269                                                  W
#
#                   original_text  \
# 0      Creature — Human Soldier
# 1      Creature — Human Soldier
# 2            Enchantment — Aura
# 3                       Sorcery
# 4                       Instant
# 5                   Enchantment
# 6                       Instant
# 7                   Enchantment
# 8            Enchantment — Aura
# 9                   Enchantment
# 10      Creature — Human Knight
# 11                      Sorcery
# 12     Creature — Human Soldier
# 13              Creature — Bird
# 14             Creature — Human
# 15           Creature — Unicorn
# 16             Creature — Beast
# 17      Creature — Human Knight
# 18             Creature — Angel
# 19   Creature — Elephant Cleric
# 20           Enchantment — Aura
# 21      Creature — Human Knight
# 22                      Instant
# 23              Creature — Bird
# 24       Creature — Human Scout
# 25     Creature — Human Soldier
# 26                      Sorcery
# 27                      Instant
# 28     Creature — Human Soldier
# 29   Creature — Elephant Cleric
# 269         Basic Land — Plains
#
#                                          original_type  legalities  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# 5                                                  NaN         NaN
# 6                                                  NaN         NaN
# 7                                                  NaN         NaN
# 8                                                  NaN         NaN
# 9                                                  NaN         NaN
# 10                                                 NaN         NaN
# 11                                                 NaN         NaN
# 12                                                 NaN         NaN
# 13                                                 NaN         NaN
# 14                                                 NaN         NaN
# 15                                                 NaN         NaN
# 16                                                 NaN         NaN
# 17                                                 NaN         NaN
# 18                                                 NaN         NaN
# 19                                                 NaN         NaN
# 20   [{'legality': 'Legal', 'format': 'Brawl'}, {'l...         NaN
# 21                                                 NaN         NaN
# 22   [{'legality': 'Legal', 'format': 'Commander'},...         NaN
# 23                                                 NaN         NaN
# 24                                                 NaN         NaN
# 25                                                 NaN         NaN
# 26                                                 NaN         NaN
# 27                                                 NaN         NaN
# 28                                                 NaN         NaN
# 29                                                 NaN         NaN
# 269  [{'legality': 'Legal', 'format': 'Brawl'}, {'l...         NaN
#
#                                                 source image_url  \
# 0    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 1    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 2    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 3    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 4    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 5    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 6    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 7    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 8    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 9    http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 10   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 11   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 12   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 13   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 14   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 15   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 16   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 17   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 18   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 19   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 20   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 21   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 22   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 23   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 24   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 25   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 26   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 27   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 28   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 29   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 269  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
#
#                    set                                  set_name  id
# 0    Guilds of Ravnica  aab699fa4415a7b8a92c5ea4146d7ed6eb184ddf NaN
# 1    Guilds of Ravnica  48f391ccf6584d74240b30ecc84d284cc433fa50 NaN
# 2    Guilds of Ravnica  61ef606f74d0c99794ac67f9bb271438d0a00243 NaN
# 3    Guilds of Ravnica  435d8dec0903635014597294dee648af6826b8d8 NaN
# 4    Guilds of Ravnica  063f0664ae618ab78a71094ed409329edbd1ee94 NaN
# 5    Guilds of Ravnica  f7af6ee1becbcac65ec44eb2b4714c4bbc88b298 NaN
# 6    Guilds of Ravnica  5d7a7776d80b9a0f0fc290dbd6ba22ec704043cd NaN
# 7    Guilds of Ravnica  700c5d0d836f8bcf85d4c57af8501c300e5f51b2 NaN
# 8    Guilds of Ravnica  118d5c4dc1b3e21b51af222b28fa72269985c5b5 NaN
# 9    Guilds of Ravnica  ea62109d90d72f2c44b52469a0504421cf33c660 NaN
# 10   Guilds of Ravnica  295f856a14064c00d127431db40f987c1de4af33 NaN
# 11   Guilds of Ravnica  5f44622e24a5a6d82216ecc1670e5b9c07f14433 NaN
# 12   Guilds of Ravnica  86b42707b84b621669ec3a98be65958612688a87 NaN
# 13   Guilds of Ravnica  a758373ca929bae581d7e348ac9e86e4ab9f6e07 NaN
# 14   Guilds of Ravnica  ea1fc76b4010d7e5f8933adb82e5b16d7a93665b NaN
# 15   Guilds of Ravnica  83eea5a2892bc6758dca55d892bcf4197151335a NaN
# 16   Guilds of Ravnica  32ad71bc6f8a1fb66e03eaefeb7a046c904f3d62 NaN
# 17   Guilds of Ravnica  ad6de3ca7492bf1c4e2b1e033dc27444e6894345 NaN
# 18   Guilds of Ravnica  bb05997b88452918614dc64ecb9664047554db6f NaN
# 19   Guilds of Ravnica  179b2760b61da0b1cf1642a79f72077571fb482d NaN
# 20   Guilds of Ravnica  1b093433c648920df703289a2c181d3424883666 NaN
# 21   Guilds of Ravnica  3171228e0b18d75fdafc03fb7c2c7147788e29ed NaN
# 22   Guilds of Ravnica  193fb571133693207251e15d7e0ad93a3db0ed3f NaN
# 23   Guilds of Ravnica  37c0d2092410c2340e7e4be67919bdd81ed41f29 NaN
# 24   Guilds of Ravnica  a13f2c6fbb874fa7972dd496f4dea7051f7cc8a8 NaN
# 25   Guilds of Ravnica  debbe395e92734c83431341f61d570a154c08e81 NaN
# 26   Guilds of Ravnica  8a3cc4a881f0a0a5566f8cee8bc17216efafa53e NaN
# 27   Guilds of Ravnica  a8fb6a4c57587d83a13871e0d477efe2aa27db1b NaN
# 28   Guilds of Ravnica  d77f61488ce74b1273c7ea331e7ac208f24c3e04 NaN
# 29   Guilds of Ravnica  03f77260240f0fa6d499fdbceae38ce2c0d72fd3 NaN
# 269  Guilds of Ravnica  7fda130df48e37c3629e25f37956a27e0315864b NaN

# %%
compare.plotListBy('name','Dimir')
# Out:
# Guilds of Ravnica
#                     name  multiverse_id  layout names mana_cost  cmc  \
# 35       Dimir Informant         452786  normal   NaN    {2}{U}    3
# 165         Dimir Spybug         452916  normal   NaN    {U}{B}    2
# 243         Dimir Locket         452984  normal   NaN       {3}    3
# 254  Dimir Guildgate (a)         452995  normal   NaN       NaN    0
# 255  Dimir Guildgate (b)         452996  normal   NaN       NaN    0
#
#                 colors color_identity                    type supertypes  \
# 35            ['Blue']          ['U']  Creature — Human Rogue        NaN
# 165  ['Blue', 'Black']     ['U', 'B']       Creature — Insect        NaN
# 243                NaN     ['U', 'B']                Artifact        NaN
# 254                NaN     ['U', 'B']             Land — Gate        NaN
# 255                NaN     ['U', 'B']             Land — Gate        NaN
#
#                subtypes    rarity  \
# 35   ['Human', 'Rogue']    Common
# 165          ['Insect']  Uncommon
# 243                 NaN    Common
# 254            ['Gate']    Common
# 255            ['Gate']    Common
#
#                                                   text  \
# 35   When Dimir Informant enters the battlefield, s...
# 165  Flying\r\nMenace (This creature can't be block...
# 243  {T}: Add {U} or {B}.\r\n{U/B}{U/B}{U/B}{U/B}, ...
# 254  Dimir Guildgate enters the battlefield tapped....
# 255  Dimir Guildgate enters the battlefield tapped....
#
#                                                 flavor          artist number  \
# 35            The letters arrive, all sealed and read.  Lucas Graciano     36
# 165       Just assume every conversation is on record.     James Paick    166
# 243  "Wear this, and take your place among the shad...     Zezhou Chen    234
# 254  "Every guild dreads infiltration. I should kno...    Cliff Childs    245
# 255  "You've found this place only because you were...    Cliff Childs    246
#
#     power  toughness  loyalty  variations watermark  border  timeshifted  \
# 35      1        4.0      NaN         NaN     Dimir     NaN          NaN
# 165     1        1.0      NaN         NaN     Dimir     NaN          NaN
# 243   NaN        NaN      NaN         NaN     Dimir     NaN          NaN
# 254   NaN        NaN      NaN         NaN     Dimir     NaN          NaN
# 255   NaN        NaN      NaN         NaN     Dimir     NaN          NaN
#
#      hand  life  reserved  release_date  \
# 35    NaN   NaN       NaN           NaN
# 165   NaN   NaN       NaN           NaN
# 243   NaN   NaN       NaN           NaN
# 254   NaN   NaN       NaN           NaN
# 255   NaN   NaN       NaN           NaN
#
#                                                starter  \
# 35   [{'text': 'When you surveil, you may put all t...
# 165  [{'text': 'You put only one +1/+1 counter on D...
# 243                                                NaN
# 254                                                NaN
# 255                                                NaN
#
#                                                rulings foreign_names  \
# 35   [{'name': 'Dimir-Informantin', 'imageUrl': 'ht...       ['GRN']
# 165  [{'name': 'Dimir-Abhörwanze', 'imageUrl': 'htt...       ['GRN']
# 243  [{'name': 'Dimir-Medaillon', 'imageUrl': 'http...       ['GRN']
# 254  [{'name': 'Dimir-Gildeneingang', 'imageUrl': '...       ['GRN']
# 255  [{'name': 'Dimir-Gildeneingang', 'imageUrl': '...       ['GRN']
#
#                                              printings  \
# 35   When Dimir Informant enters the battlefield, s...
# 165  Flying\r\nMenace <i>(This creature can't be bl...
# 243  {T}: Add {U} or {B}.\r\n{U/B}{U/B}{U/B}{U/B}, ...
# 254  Dimir Guildgate enters the battlefield tapped....
# 255  Dimir Guildgate enters the battlefield tapped....
#
#               original_text original_type  legalities  \
# 35   Creature — Human Rogue           NaN         NaN
# 165       Creature — Insect           NaN         NaN
# 243                Artifact           NaN         NaN
# 254             Land — Gate           NaN         NaN
# 255             Land — Gate           NaN         NaN
#
#                                                 source image_url  \
# 35   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 165  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 243  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 254  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 255  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
#
#                    set                                  set_name  id
# 35   Guilds of Ravnica  56c407aae041d2a2588a7f6f57304d5abb9b03f4 NaN
# 165  Guilds of Ravnica  54aed526c80249fd1258f4d45dd82cbdb2117955 NaN
# 243  Guilds of Ravnica  03ebe38c3315a6d8baa16d857bb7d142220b2d12 NaN
# 254  Guilds of Ravnica  a86f254a2d716672248aa460505bcd703bae63aa NaN
# 255  Guilds of Ravnica  cb70251a22ecc2d9826b488166c303f2b7631abd NaN
