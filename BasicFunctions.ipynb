# %%
#This class is used to download all the sets and cards information
import src.downloadProcess as dMtgInfo
#This class has all the analytical functions
import src.mtgBaseClass as mbc
import src.cardSet as cs

# %% [markdown]
# Before start using the analitycal class you need to run the next cell to donwload all the Sets information

# %%
downloadClass = dMtgInfo.downloadMtgInfo()

#Downloading the set list
downloadClass.downloadSets()

#Downloading all the cards of each set
downloadClass.downloadCards()

# %%
#In this array you can insert all the sets that you want to check
setList = ['Guilds of Ravnica']
compare = mbc.mtgBase(setList)

# %%
#Plot the total of cards of each set
compare.plotCardsTotal()

# %%
#Plot the median CMC per rarity of each set
compare.plotMedianCmc()

# %% [markdown]
# You can filter the cardSetList using the function "filterCardSetListBy" and then selecting the column that you want to filter
# and then the value that will be filtred.
#
# In this case it will filter by all the cards that have the word "soldiers" in the flavor text

# %%
list = compare.filterCardSetListBy(compare.cardSetList,compare.card.flavor,'soldiers')
compare.plotCardSetList(list)
# Out:
# Guilds of Ravnica
#                 name  multiverse_id  layout names mana_cost  cmc     colors  \
# 27        Take Heart         452778  normal   NaN       {W}    1  ['White']
# 52   Selective Snare         452803  normal   NaN    {X}{U}    1   ['Blue']
# 240     Boros Locket         452981  normal   NaN       {3}    3        NaN
#
#     color_identity      type supertypes subtypes    rarity  \
# 27           ['W']   Instant        NaN      NaN    Common
# 52           ['U']   Sorcery        NaN      NaN  Uncommon
# 240     ['R', 'W']  Artifact        NaN      NaN    Common
#
#                                                   text  \
# 27   Target creature gets +2/+2 until end of turn. ...
# 52   Return X target creatures of the creature type...
# 240  {T}: Add {R} or {W}.\r\n{R/W}{R/W}{R/W}{R/W}, ...
#
#                                                 flavor          artist number  \
# 27   In the quiet before a battle, Boros soldiers w...  Lucas Graciano     28
# 52   "How thoughtful of the Legion to train its sol...    Alex Konstad     53
# 240  "We pass these along to our fellow soldiers to...    Aaron Miller    231
#
#     power  toughness  loyalty  variations watermark  border  timeshifted  \
# 27    NaN        NaN      NaN         NaN       NaN     NaN          NaN
# 52    NaN        NaN      NaN         NaN       NaN     NaN          NaN
# 240   NaN        NaN      NaN         NaN     Boros     NaN          NaN
#
#      hand  life  reserved  release_date  \
# 27    NaN   NaN       NaN           NaN
# 52    NaN   NaN       NaN           NaN
# 240   NaN   NaN       NaN           NaN
#
#                                                starter  \
# 27   [{'text': "You can cast Take Heart even if you...
# 52   [{'text': 'To choose a creature type, you must...
# 240                                                NaN
#
#                                                rulings foreign_names  \
# 27   [{'name': 'Ein Herz fassen', 'imageUrl': 'http...       ['GRN']
# 52   [{'name': 'Selektive Falle', 'imageUrl': 'http...       ['GRN']
# 240  [{'name': 'Boros-Medaillon', 'imageUrl': 'http...       ['GRN']
#
#                                              printings original_text  \
# 27   Target creature gets +2/+2 until end of turn. ...       Instant
# 52   Return X target creatures of the creature type...       Sorcery
# 240  {T}: Add {R} or {W}.\r\n{R/W}{R/W}{R/W}{R/W}, ...      Artifact
#
#     original_type  legalities  \
# 27            NaN         NaN
# 52            NaN         NaN
# 240           NaN         NaN
#
#                                                 source image_url  \
# 27   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 52   http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 240  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
#
#                    set                                  set_name  id
# 27   Guilds of Ravnica  a8fb6a4c57587d83a13871e0d477efe2aa27db1b NaN
# 52   Guilds of Ravnica  e3b9e1c99fc39b0036f61cc46ca11306fdc9555a NaN
# 240  Guilds of Ravnica  91571d8ca0ebf628f8bda42ec40703bd70a5999d NaN

# %% [markdown]
# You can also do more complex filtering using function like 'returnColorIdentity'

# %%
list = compare.filterCardSetListBy(compare.cardSetList,compare.card.color_identity,compare.colorPie.returnColorIdentity(True,False,False,True))
compare.plotCardSetList(list)
# Out:
# Guilds of Ravnica
#                              name  multiverse_id  layout  \
# 0                Blade Instructor         452751  normal
# 1                    Bounty Agent         452752  normal
# 2               Candlelight Vigil         452753  normal
# 3                   Citywide Bust         452754  normal
# 4              Collar the Culprit         452755  normal
# 5               Conclave Tribunal         452756  normal
# 6                Crush Contraband         452757  normal
# 7                    Dawn of Hope         452758  normal
# 8                        Demotion         452759  normal
# 9               Divine Visitation         452760  normal
# 10            Flight of Equenauts         452761  normal
# 11                Gird for Battle         452762  normal
# 12                 Haazda Marshal         452763  normal
# 13                  Healer's Hawk         452764  normal
# 14                 Hunted Witness         452765  normal
# 15              Inspiring Unicorn         452766  normal
# 16            Intrusive Packbeast         452767  normal
# 17                 Ledev Guardian         452768  normal
# 18            Light of the Legion         452769  normal
# 19               Loxodon Restorer         452770  normal
# 20                 Luminous Bonds         452771  normal
# 21               Parhelion Patrol         452772  normal
# 22                 Righteous Blow         452773  normal
# 23                    Roc Charger         452774  normal
# 24                  Skyline Scout         452775  normal
# 25               Sunhome Stalwart         452776  normal
# 26               Sworn Companions         452777  normal
# 27                     Take Heart         452778  normal
# 28           Tenth District Guard         452779  normal
# 29              Venerated Loxodon         452780  normal
# 90               Arclight Phoenix         452841  normal
# 91               Barging Sergeant         452842  normal
# 92                  Book Devourer         452843  normal
# 93              Command the Storm         452844  normal
# 94               Cosmotronic Wave         452845  normal
# 95                 Direct Current         452846  normal
# 96            Electrostatic Field         452847  normal
# 97                Erratic Cyclops         452848  normal
# 98            Experimental Frenzy         452849  normal
# 99            Fearless Halberdier         452850  normal
# 100                   Fire Urchin         452851  normal
# 101               Goblin Banneret         452852  normal
# 102            Goblin Cratermaker         452853  normal
# 103              Goblin Locksmith         452854  normal
# 104                Gravitic Punch         452855  normal
# 105                Hellkite Whelp         452856  normal
# 106             Inescapable Blaze         452857  normal
# 107                     Lava Coil         452858  normal
# 108                Legion Warboss         452859  normal
# 109                 Maniacal Rage         452860  normal
# 110             Maximize Velocity         452861  normal
# 111                 Ornery Goblin         452862  normal
# 112                   Risk Factor         452863  normal
# 113               Rubblebelt Boar         452864  normal
# 114             Runaway Steam-Kin         452865  normal
# 115           Smelt-Ward Minotaur         452866  normal
# 116                   Street Riot         452867  normal
# 117                   Sure Strike         452868  normal
# 118                 Torch Courier         452869  normal
# 119               Wojek Bodyguard         452870  normal
# 152  Aurelia, Exemplar of Justice         452903  normal
# 153                   Beacon Bolt         452904  normal
# 154             Beamsplitter Mage         452905  normal
# 155              Boros Challenger         452906  normal
# 156                   Camaraderie         452907  normal
# 157            Centaur Peacemaker         452908  normal
# 158              Chance for Glory         452909  normal
# 160             Conclave Cavalier         452911  normal
# 161            Conclave Guildmage         452912  normal
# 162               Crackling Drake         452913  normal
# 164             Deafening Clarion         452915  normal
# 167    Emmara, Soul of the Accord         452918  normal
# 170           Firemind's Research         452921  normal
# 171             Garrison Sergeant         452922  normal
# 173          Goblin Electromancer         452924  normal
# 175                Hammer Dropper         452926  normal
# 177                 Hypothesizzle         452928  normal
# 178                        Ionize         452929  normal
# 180                  Join Shields         452931  normal
# 181                Justice Strike         452932  normal
# 182              Knight of Autumn         452933  normal
# 184              League Guildmage         452935  normal
# 185                Ledev Champion         452936  normal
# 186              Legion Guildmage         452937  normal
# 187       March of the Multitudes         452938  normal
# 191             Niv-Mizzet, Parun         452942  normal
# 194            Ral, Izzet Viceroy         452945  normal
# 196              Rosemane Centaur         452947  normal
# 197         Skyknight Legionnaire         452948  normal
# 198                 Sonic Assault         452949  normal
# 199             Sumala Woodshaper         452950  normal
# 201             Swathcutter Giant         452952  normal
# 202         Swiftblade Vindicator         452953  normal
# 203          Tajic, Legion's Edge         452954  normal
# 206           Thousand-Year Storm         452957  normal
# 207           Trostani Discordant         452958  normal
# 208              Truefire Captain         452959  normal
# 213                Wee Dragonauts         452964  normal
# 214            Worldsoul Colossus         452965  normal
# 215           Fresh-Faced Recruit         452966  normal
# 216           Piston-Fist Cyclops         452967  normal
# 218            Vernadi Shieldmate         452969  normal
# 220                        Assure         452971   split
# 221                      Assemble         452971   split
# 226                     Expansion         452974   split
# 227                     Explosion         452974   split
# 230                        Flower         452976   split
# 231                      Flourish         452976   split
# 232                     Integrity         452977   split
# 233                  Intervention         452977   split
# 234                        Invert         452978   split
# 235                        Invent         452978   split
# 236                      Response         452979   split
# 237                    Resurgence         452979   split
# 240                  Boros Locket         452981  normal
# 241                Chamber Sentry         452982  normal
# 247                  Izzet Locket         452988  normal
# 249               Selesnya Locket         452990  normal
# 252           Boros Guildgate (a)         452993  normal
# 253           Boros Guildgate (b)         452994  normal
# 260           Izzet Guildgate (a)         453001  normal
# 261           Izzet Guildgate (b)         453002  normal
# 263                Sacred Foundry         453004  normal
# 264        Selesnya Guildgate (a)         453005  normal
# 265        Selesnya Guildgate (b)         453006  normal
# 266                   Steam Vents         453007  normal
# 267                 Temple Garden         453008  normal
# 269                        Plains         455600  normal
# 272                      Mountain         455603  normal
# 274         Ral, Caller of Storms         455605  normal
# 276                Precision Bolt         455607  normal
# 277             Ral's Staticaster         455608  normal
#
#                              names           mana_cost  cmc  \
# 0                              NaN              {2}{W}    3
# 1                              NaN              {1}{W}    2
# 2                              NaN              {3}{W}    4
# 3                              NaN           {1}{W}{W}    3
# 4                              NaN              {3}{W}    4
# 5                              NaN              {3}{W}    4
# 6                              NaN              {3}{W}    4
# 7                              NaN              {1}{W}    2
# 8                              NaN                 {W}    1
# 9                              NaN           {3}{W}{W}    5
# 10                             NaN              {7}{W}    8
# 11                             NaN                 {W}    1
# 12                             NaN                 {W}    1
# 13                             NaN                 {W}    1
# 14                             NaN                 {W}    1
# 15                             NaN           {2}{W}{W}    4
# 16                             NaN              {4}{W}    5
# 17                             NaN              {3}{W}    4
# 18                             NaN           {4}{W}{W}    6
# 19                             NaN           {4}{W}{W}    6
# 20                             NaN              {2}{W}    3
# 21                             NaN              {3}{W}    4
# 22                             NaN                 {W}    1
# 23                             NaN              {2}{W}    3
# 24                             NaN              {1}{W}    2
# 25                             NaN              {1}{W}    2
# 26                             NaN              {2}{W}    3
# 27                             NaN                 {W}    1
# 28                             NaN              {1}{W}    2
# 29                             NaN              {4}{W}    5
# 90                             NaN              {3}{R}    4
# 91                             NaN              {4}{R}    5
# 92                             NaN              {5}{R}    6
# 93                             NaN              {4}{R}    5
# 94                             NaN              {3}{R}    4
# 95                             NaN           {1}{R}{R}    3
# 96                             NaN              {1}{R}    2
# 97                             NaN              {3}{R}    4
# 98                             NaN              {3}{R}    4
# 99                             NaN              {2}{R}    3
# 100                            NaN              {1}{R}    2
# 101                            NaN                 {R}    1
# 102                            NaN              {1}{R}    2
# 103                            NaN              {1}{R}    2
# 104                            NaN              {3}{R}    4
# 105                            NaN              {4}{R}    5
# 106                            NaN           {4}{R}{R}    6
# 107                            NaN              {1}{R}    2
# 108                            NaN              {2}{R}    3
# 109                            NaN              {1}{R}    2
# 110                            NaN                 {R}    1
# 111                            NaN              {1}{R}    2
# 112                            NaN              {2}{R}    3
# 113                            NaN              {3}{R}    4
# 114                            NaN              {1}{R}    2
# 115                            NaN              {2}{R}    3
# 116                            NaN              {4}{R}    5
# 117                            NaN              {1}{R}    2
# 118                            NaN                 {R}    1
# 119                            NaN              {2}{R}    3
# 152                            NaN           {2}{R}{W}    4
# 153                            NaN           {1}{U}{R}    3
# 154                            NaN              {U}{R}    2
# 155                            NaN              {R}{W}    2
# 156                            NaN           {4}{G}{W}    6
# 157                            NaN           {1}{G}{W}    3
# 158                            NaN           {1}{R}{W}    3
# 160                            NaN        {G}{G}{W}{W}    4
# 161                            NaN              {G}{W}    2
# 162                            NaN        {U}{U}{R}{R}    4
# 164                            NaN           {1}{R}{W}    3
# 167                            NaN              {G}{W}    2
# 170                            NaN              {U}{R}    2
# 171                            NaN           {3}{R}{W}    5
# 173                            NaN              {U}{R}    2
# 175                            NaN           {2}{R}{W}    4
# 177                            NaN           {3}{U}{R}    5
# 178                            NaN           {1}{U}{R}    3
# 180                            NaN           {3}{G}{W}    5
# 181                            NaN              {R}{W}    2
# 182                            NaN           {1}{G}{W}    3
# 184                            NaN              {U}{R}    2
# 185                            NaN           {1}{G}{W}    3
# 186                            NaN              {R}{W}    2
# 187                            NaN        {X}{G}{W}{W}    3
# 191                            NaN  {U}{U}{U}{R}{R}{R}    6
# 194                            NaN           {3}{U}{R}    5
# 196                            NaN           {3}{G}{W}    5
# 197                            NaN           {1}{R}{W}    3
# 198                            NaN           {1}{U}{R}    3
# 199                            NaN           {2}{G}{W}    4
# 201                            NaN           {4}{R}{W}    6
# 202                            NaN              {R}{W}    2
# 203                            NaN           {1}{R}{W}    3
# 206                            NaN           {4}{U}{R}    6
# 207                            NaN           {3}{G}{W}    5
# 208                            NaN        {R}{R}{W}{W}    4
# 213                            NaN           {1}{U}{R}    3
# 214                            NaN           {X}{G}{W}    2
# 215                            NaN            {1}{R/W}    2
# 216                            NaN       {1}{U/R}{U/R}    3
# 218                            NaN            {1}{G/W}    2
# 220         ['Assure', 'Assemble']          {G/W}{G/W}    2
# 221         ['Assure', 'Assemble']           {4}{G}{W}    6
# 226     ['Expansion', 'Explosion']          {U/R}{U/R}    2
# 227     ['Expansion', 'Explosion']     {X}{U}{U}{R}{R}    4
# 230         ['Flower', 'Flourish']               {G/W}    1
# 231         ['Flower', 'Flourish']           {4}{G}{W}    6
# 232  ['Integrity', 'Intervention']               {R/W}    1
# 233  ['Integrity', 'Intervention']           {2}{R}{W}    4
# 234           ['Invert', 'Invent']               {U/R}    1
# 235           ['Invert', 'Invent']           {4}{U}{R}    6
# 236     ['Response', 'Resurgence']          {R/W}{R/W}    2
# 237     ['Response', 'Resurgence']           {3}{R}{W}    5
# 240                            NaN                 {3}    3
# 241                            NaN                 {X}    0
# 247                            NaN                 {3}    3
# 249                            NaN                 {3}    3
# 252                            NaN                 NaN    0
# 253                            NaN                 NaN    0
# 260                            NaN                 NaN    0
# 261                            NaN                 NaN    0
# 263                            NaN                 NaN    0
# 264                            NaN                 NaN    0
# 265                            NaN                 NaN    0
# 266                            NaN                 NaN    0
# 267                            NaN                 NaN    0
# 269                            NaN                 NaN    0
# 272                            NaN                 NaN    0
# 274                            NaN           {4}{U}{R}    6
# 276                            NaN              {2}{R}    3
# 277                            NaN           {2}{U}{R}    4
#
#                  colors             color_identity  \
# 0             ['White']                      ['W']
# 1             ['White']                      ['W']
# 2             ['White']                      ['W']
# 3             ['White']                      ['W']
# 4             ['White']                      ['W']
# 5             ['White']                      ['W']
# 6             ['White']                      ['W']
# 7             ['White']                      ['W']
# 8             ['White']                      ['W']
# 9             ['White']                      ['W']
# 10            ['White']                      ['W']
# 11            ['White']                      ['W']
# 12            ['White']                      ['W']
# 13            ['White']                      ['W']
# 14            ['White']                      ['W']
# 15            ['White']                      ['W']
# 16            ['White']                      ['W']
# 17            ['White']                      ['W']
# 18            ['White']                      ['W']
# 19            ['White']                      ['W']
# 20            ['White']                      ['W']
# 21            ['White']                      ['W']
# 22            ['White']                      ['W']
# 23            ['White']                      ['W']
# 24            ['White']                      ['W']
# 25            ['White']                      ['W']
# 26            ['White']                      ['W']
# 27            ['White']                      ['W']
# 28            ['White']                      ['W']
# 29            ['White']                      ['W']
# 90              ['Red']                      ['R']
# 91              ['Red']                      ['R']
# 92              ['Red']                      ['R']
# 93              ['Red']                      ['R']
# 94              ['Red']                      ['R']
# 95              ['Red']                      ['R']
# 96              ['Red']                      ['R']
# 97              ['Red']                      ['R']
# 98              ['Red']                      ['R']
# 99              ['Red']                      ['R']
# 100             ['Red']                      ['R']
# 101             ['Red']                      ['R']
# 102             ['Red']                      ['R']
# 103             ['Red']                      ['R']
# 104             ['Red']                      ['R']
# 105             ['Red']                      ['R']
# 106             ['Red']                      ['R']
# 107             ['Red']                      ['R']
# 108             ['Red']                      ['R']
# 109             ['Red']                      ['R']
# 110             ['Red']                      ['R']
# 111             ['Red']                      ['R']
# 112             ['Red']                      ['R']
# 113             ['Red']                      ['R']
# 114             ['Red']                      ['R']
# 115             ['Red']                      ['R']
# 116             ['Red']                      ['R']
# 117             ['Red']                      ['R']
# 118             ['Red']                      ['R']
# 119             ['Red']                      ['R']
# 152    ['White', 'Red']                 ['W', 'R']
# 153     ['Blue', 'Red']                 ['U', 'R']
# 154     ['Blue', 'Red']                 ['U', 'R']
# 155    ['White', 'Red']                 ['W', 'R']
# 156  ['White', 'Green']                 ['W', 'G']
# 157  ['White', 'Green']                 ['W', 'G']
# 158    ['White', 'Red']                 ['W', 'R']
# 160  ['White', 'Green']                 ['W', 'G']
# 161  ['White', 'Green']                 ['W', 'G']
# 162     ['Blue', 'Red']                 ['U', 'R']
# 164    ['White', 'Red']                 ['W', 'R']
# 167  ['White', 'Green']                 ['W', 'G']
# 170     ['Blue', 'Red']                 ['U', 'R']
# 171    ['White', 'Red']                 ['W', 'R']
# 173     ['Blue', 'Red']                 ['U', 'R']
# 175    ['White', 'Red']                 ['W', 'R']
# 177     ['Blue', 'Red']                 ['U', 'R']
# 178     ['Blue', 'Red']                 ['U', 'R']
# 180  ['White', 'Green']                 ['W', 'G']
# 181    ['White', 'Red']                 ['W', 'R']
# 182  ['White', 'Green']                 ['W', 'G']
# 184     ['Blue', 'Red']                 ['U', 'R']
# 185  ['White', 'Green']                 ['W', 'G']
# 186    ['White', 'Red']                 ['W', 'R']
# 187  ['White', 'Green']                 ['W', 'G']
# 191     ['Blue', 'Red']                 ['U', 'R']
# 194     ['Blue', 'Red']                 ['U', 'R']
# 196  ['White', 'Green']                 ['W', 'G']
# 197    ['White', 'Red']                 ['W', 'R']
# 198     ['Blue', 'Red']                 ['U', 'R']
# 199  ['White', 'Green']                 ['W', 'G']
# 201    ['White', 'Red']                 ['W', 'R']
# 202    ['White', 'Red']                 ['W', 'R']
# 203    ['White', 'Red']                 ['W', 'R']
# 206     ['Blue', 'Red']                 ['U', 'R']
# 207  ['White', 'Green']                 ['W', 'G']
# 208    ['White', 'Red']                 ['W', 'R']
# 213     ['Blue', 'Red']                 ['U', 'R']
# 214  ['White', 'Green']                 ['W', 'G']
# 215    ['White', 'Red']                 ['W', 'R']
# 216     ['Blue', 'Red']                 ['U', 'R']
# 218  ['White', 'Green']                 ['W', 'G']
# 220  ['White', 'Green']                 ['W', 'G']
# 221  ['White', 'Green']                 ['W', 'G']
# 226     ['Blue', 'Red']                 ['U', 'R']
# 227     ['Blue', 'Red']                 ['U', 'R']
# 230  ['White', 'Green']                 ['W', 'G']
# 231  ['White', 'Green']                 ['W', 'G']
# 232    ['White', 'Red']                 ['W', 'R']
# 233    ['White', 'Red']                 ['W', 'R']
# 234     ['Blue', 'Red']                 ['U', 'R']
# 235     ['Blue', 'Red']                 ['U', 'R']
# 236    ['White', 'Red']                 ['W', 'R']
# 237    ['White', 'Red']                 ['W', 'R']
# 240                 NaN                 ['R', 'W']
# 241                 NaN  ['W', 'U', 'B', 'R', 'G']
# 247                 NaN                 ['U', 'R']
# 249                 NaN                 ['G', 'W']
# 252                 NaN                 ['R', 'W']
# 253                 NaN                 ['R', 'W']
# 260                 NaN                 ['U', 'R']
# 261                 NaN                 ['U', 'R']
# 263                 NaN                 ['W', 'R']
# 264                 NaN                 ['G', 'W']
# 265                 NaN                 ['G', 'W']
# 266                 NaN                 ['U', 'R']
# 267                 NaN                 ['W', 'G']
# 269                 NaN                      ['W']
# 272                 NaN                      ['R']
# 274     ['Blue', 'Red']                 ['U', 'R']
# 276             ['Red']                      ['R']
# 277     ['Blue', 'Red']                 ['U', 'R']
#
#                                    type     supertypes  \
# 0              Creature — Human Soldier            NaN
# 1              Creature — Human Soldier            NaN
# 2                    Enchantment — Aura            NaN
# 3                               Sorcery            NaN
# 4                               Instant            NaN
# 5                           Enchantment            NaN
# 6                               Instant            NaN
# 7                           Enchantment            NaN
# 8                    Enchantment — Aura            NaN
# 9                           Enchantment            NaN
# 10              Creature — Human Knight            NaN
# 11                              Sorcery            NaN
# 12             Creature — Human Soldier            NaN
# 13                      Creature — Bird            NaN
# 14                     Creature — Human            NaN
# 15                   Creature — Unicorn            NaN
# 16                     Creature — Beast            NaN
# 17              Creature — Human Knight            NaN
# 18                     Creature — Angel            NaN
# 19           Creature — Elephant Cleric            NaN
# 20                   Enchantment — Aura            NaN
# 21              Creature — Human Knight            NaN
# 22                              Instant            NaN
# 23                      Creature — Bird            NaN
# 24               Creature — Human Scout            NaN
# 25             Creature — Human Soldier            NaN
# 26                              Sorcery            NaN
# 27                              Instant            NaN
# 28             Creature — Human Soldier            NaN
# 29           Creature — Elephant Cleric            NaN
# 90                   Creature — Phoenix            NaN
# 91          Creature — Minotaur Soldier            NaN
# 92                     Creature — Beast            NaN
# 93                              Instant            NaN
# 94                              Sorcery            NaN
# 95                              Sorcery            NaN
# 96                      Creature — Wall            NaN
# 97            Creature — Cyclops Shaman            NaN
# 98                          Enchantment            NaN
# 99             Creature — Human Warrior            NaN
# 100                Creature — Elemental            NaN
# 101           Creature — Goblin Soldier            NaN
# 102           Creature — Goblin Warrior            NaN
# 103             Creature — Goblin Rogue            NaN
# 104                             Sorcery            NaN
# 105                   Creature — Dragon            NaN
# 106                             Instant            NaN
# 107                             Sorcery            NaN
# 108           Creature — Goblin Soldier            NaN
# 109                  Enchantment — Aura            NaN
# 110                             Sorcery            NaN
# 111           Creature — Goblin Warrior            NaN
# 112                             Instant            NaN
# 113                     Creature — Boar            NaN
# 114                Creature — Elemental            NaN
# 115         Creature — Minotaur Warrior            NaN
# 116                         Enchantment            NaN
# 117                             Instant            NaN
# 118                   Creature — Goblin            NaN
# 119            Creature — Human Soldier            NaN
# 152          Legendary Creature — Angel  ['Legendary']
# 153                             Sorcery            NaN
# 154          Creature — Vedalken Wizard            NaN
# 155            Creature — Human Soldier            NaN
# 156                             Sorcery            NaN
# 157           Creature — Centaur Cleric            NaN
# 158                             Instant            NaN
# 160           Creature — Centaur Knight            NaN
# 161               Creature — Elf Cleric            NaN
# 162                    Creature — Drake            NaN
# 164                             Sorcery            NaN
# 167     Legendary Creature — Elf Cleric  ['Legendary']
# 170                         Enchantment            NaN
# 171         Creature — Viashino Soldier            NaN
# 173            Creature — Goblin Wizard            NaN
# 175            Creature — Giant Soldier            NaN
# 177                             Instant            NaN
# 178                             Instant            NaN
# 180                             Instant            NaN
# 181                             Instant            NaN
# 182             Creature — Dryad Knight            NaN
# 184             Creature — Human Wizard            NaN
# 185               Creature — Elf Knight            NaN
# 186             Creature — Human Wizard            NaN
# 187                             Instant            NaN
# 191  Legendary Creature — Dragon Wizard  ['Legendary']
# 194        Legendary Planeswalker — Ral  ['Legendary']
# 196          Creature — Centaur Soldier            NaN
# 197             Creature — Human Knight            NaN
# 198                             Instant            NaN
# 199                Creature — Elf Druid            NaN
# 201            Creature — Giant Soldier            NaN
# 202            Creature — Human Soldier            NaN
# 203  Legendary Creature — Human Soldier  ['Legendary']
# 206                         Enchantment            NaN
# 207          Legendary Creature — Dryad  ['Legendary']
# 208             Creature — Human Knight            NaN
# 213            Creature — Faerie Wizard            NaN
# 214                Creature — Elemental            NaN
# 215            Creature — Human Soldier            NaN
# 216                  Creature — Cyclops            NaN
# 218            Creature — Human Soldier            NaN
# 220                             Instant            NaN
# 221                             Instant            NaN
# 226                             Instant            NaN
# 227                             Instant            NaN
# 230                             Sorcery            NaN
# 231                             Sorcery            NaN
# 232                             Instant            NaN
# 233                             Instant            NaN
# 234                             Instant            NaN
# 235                             Instant            NaN
# 236                             Instant            NaN
# 237                             Sorcery            NaN
# 240                            Artifact            NaN
# 241       Artifact Creature — Construct            NaN
# 247                            Artifact            NaN
# 249                            Artifact            NaN
# 252                         Land — Gate            NaN
# 253                         Land — Gate            NaN
# 260                         Land — Gate            NaN
# 261                         Land — Gate            NaN
# 263              Land — Mountain Plains            NaN
# 264                         Land — Gate            NaN
# 265                         Land — Gate            NaN
# 266              Land — Island Mountain            NaN
# 267                Land — Forest Plains            NaN
# 269                 Basic Land — Plains      ['Basic']
# 272               Basic Land — Mountain      ['Basic']
# 274        Legendary Planeswalker — Ral  ['Legendary']
# 276                             Sorcery            NaN
# 277          Creature — Viashino Wizard            NaN
#
#                     subtypes       rarity  \
# 0       ['Human', 'Soldier']       Common
# 1       ['Human', 'Soldier']         Rare
# 2                   ['Aura']       Common
# 3                        NaN         Rare
# 4                        NaN       Common
# 5                        NaN     Uncommon
# 6                        NaN     Uncommon
# 7                        NaN         Rare
# 8                   ['Aura']     Uncommon
# 9                        NaN  Mythic Rare
# 10       ['Human', 'Knight']     Uncommon
# 11                       NaN     Uncommon
# 12      ['Human', 'Soldier']     Uncommon
# 13                  ['Bird']       Common
# 14                 ['Human']       Common
# 15               ['Unicorn']     Uncommon
# 16                 ['Beast']       Common
# 17       ['Human', 'Knight']       Common
# 18                 ['Angel']         Rare
# 19    ['Elephant', 'Cleric']       Common
# 20                  ['Aura']       Common
# 21       ['Human', 'Knight']       Common
# 22                       NaN       Common
# 23                  ['Bird']     Uncommon
# 24        ['Human', 'Scout']       Common
# 25      ['Human', 'Soldier']     Uncommon
# 26                       NaN       Common
# 27                       NaN       Common
# 28      ['Human', 'Soldier']       Common
# 29    ['Elephant', 'Cleric']         Rare
# 90               ['Phoenix']  Mythic Rare
# 91   ['Minotaur', 'Soldier']       Common
# 92                 ['Beast']     Uncommon
# 93                       NaN       Common
# 94                       NaN       Common
# 95                       NaN       Common
# 96                  ['Wall']     Uncommon
# 97     ['Cyclops', 'Shaman']         Rare
# 98                       NaN         Rare
# 99      ['Human', 'Warrior']       Common
# 100            ['Elemental']       Common
# 101    ['Goblin', 'Soldier']     Uncommon
# 102    ['Goblin', 'Warrior']     Uncommon
# 103      ['Goblin', 'Rogue']       Common
# 104                      NaN       Common
# 105               ['Dragon']     Uncommon
# 106                      NaN     Uncommon
# 107                      NaN     Uncommon
# 108    ['Goblin', 'Soldier']         Rare
# 109                 ['Aura']       Common
# 110                      NaN       Common
# 111    ['Goblin', 'Warrior']       Common
# 112                      NaN         Rare
# 113                 ['Boar']       Common
# 114            ['Elemental']         Rare
# 115  ['Minotaur', 'Warrior']     Uncommon
# 116                      NaN     Uncommon
# 117                      NaN       Common
# 118               ['Goblin']       Common
# 119     ['Human', 'Soldier']       Common
# 152                ['Angel']  Mythic Rare
# 153                      NaN     Uncommon
# 154   ['Vedalken', 'Wizard']     Uncommon
# 155     ['Human', 'Soldier']     Uncommon
# 156                      NaN         Rare
# 157    ['Centaur', 'Cleric']       Common
# 158                      NaN  Mythic Rare
# 160    ['Centaur', 'Knight']     Uncommon
# 161        ['Elf', 'Cleric']     Uncommon
# 162                ['Drake']     Uncommon
# 164                      NaN         Rare
# 167        ['Elf', 'Cleric']         Rare
# 170                      NaN         Rare
# 171  ['Viashino', 'Soldier']       Common
# 173     ['Goblin', 'Wizard']       Common
# 175     ['Giant', 'Soldier']       Common
# 177                      NaN       Common
# 178                      NaN         Rare
# 180                      NaN     Uncommon
# 181                      NaN     Uncommon
# 182      ['Dryad', 'Knight']         Rare
# 184      ['Human', 'Wizard']     Uncommon
# 185        ['Elf', 'Knight']     Uncommon
# 186      ['Human', 'Wizard']     Uncommon
# 187                      NaN  Mythic Rare
# 191     ['Dragon', 'Wizard']         Rare
# 194                  ['Ral']  Mythic Rare
# 196   ['Centaur', 'Soldier']       Common
# 197      ['Human', 'Knight']       Common
# 198                      NaN       Common
# 199         ['Elf', 'Druid']       Common
# 201     ['Giant', 'Soldier']     Uncommon
# 202     ['Human', 'Soldier']         Rare
# 203     ['Human', 'Soldier']         Rare
# 206                      NaN  Mythic Rare
# 207                ['Dryad']  Mythic Rare
# 208      ['Human', 'Knight']     Uncommon
# 213     ['Faerie', 'Wizard']     Uncommon
# 214            ['Elemental']     Uncommon
# 215     ['Human', 'Soldier']       Common
# 216              ['Cyclops']       Common
# 218     ['Human', 'Soldier']       Common
# 220                      NaN         Rare
# 221                      NaN         Rare
# 226                      NaN         Rare
# 227                      NaN         Rare
# 230                      NaN     Uncommon
# 231                      NaN     Uncommon
# 232                      NaN     Uncommon
# 233                      NaN     Uncommon
# 234                      NaN     Uncommon
# 235                      NaN     Uncommon
# 236                      NaN         Rare
# 237                      NaN         Rare
# 240                      NaN       Common
# 241            ['Construct']         Rare
# 247                      NaN       Common
# 249                      NaN       Common
# 252                 ['Gate']       Common
# 253                 ['Gate']       Common
# 260                 ['Gate']       Common
# 261                 ['Gate']       Common
# 263   ['Mountain', 'Plains']         Rare
# 264                 ['Gate']       Common
# 265                 ['Gate']       Common
# 266   ['Island', 'Mountain']         Rare
# 267     ['Forest', 'Plains']         Rare
# 269               ['Plains']   Basic Land
# 272             ['Mountain']   Basic Land
# 274                  ['Ral']  Mythic Rare
# 276                      NaN       Common
# 277   ['Viashino', 'Wizard']     Uncommon
#
#                                                   text  \
# 0    Mentor (Whenever this creature attacks, put a ...
# 1    Vigilance\r\n{T}, Sacrifice Bounty Agent: Dest...
# 2    Enchant creature\r\nEnchanted creature gets +3...
# 3    Destroy all creatures with toughness 4 or grea...
# 4    Destroy target creature with toughness 4 or gr...
# 5    Convoke (Your creatures can help cast this spe...
# 6    Choose one or both —\r\n• Exile target artifac...
# 7    Whenever you gain life, you may pay {2}. If yo...
# 8    Enchant creature\r\nEnchanted creature can't b...
# 9    If one or more creature tokens would be create...
# 10   Convoke (Your creatures can help cast this spe...
# 11   Put a +1/+1 counter on each of up to two targe...
# 12   Whenever Haazda Marshal and at least two other...
# 13                                    Flying, lifelink
# 14   When Hunted Witness dies, create a 1/1 white S...
# 15   Whenever Inspiring Unicorn attacks, creatures ...
# 16   Vigilance\r\nWhen Intrusive Packbeast enters t...
# 17   Convoke (Your creatures can help cast this spe...
# 18   Flying\r\nMentor (Whenever this creature attac...
# 19   Convoke (Your creatures can help cast this spe...
# 20   Enchant creature\r\nEnchanted creature can't a...
# 21   Flying, vigilance\r\nMentor (Whenever this cre...
# 22   Righteous Blow deals 2 damage to target attack...
# 23   Flying\r\nWhenever Roc Charger attacks, target...
# 24   Whenever Skyline Scout attacks, you may pay {1...
# 25   First strike\r\nMentor (Whenever this creature...
# 26   Create two 1/1 white Soldier creature tokens w...
# 27   Target creature gets +2/+2 until end of turn. ...
# 28   When Tenth District Guard enters the battlefie...
# 29   Convoke (Your creatures can help cast this spe...
# 90   Flying, haste\r\nAt the beginning of combat on...
# 91   Haste\r\nMentor (Whenever this creature attack...
# 92   Trample\r\nWhenever Book Devourer deals combat...
# 93   Command the Storm deals 5 damage to target cre...
# 94   Cosmotronic Wave deals 1 damage to each creatu...
# 95   Direct Current deals 2 damage to any target.\r...
# 96   Defender\r\nWhenever you cast an instant or so...
# 97   Trample\r\nWhenever you cast an instant or sor...
# 98   You may look at the top card of your library a...
# 99                                                 NaN
# 100  Trample\r\nWhenever you cast an instant or sor...
# 101  Mentor (Whenever this creature attacks, put a ...
# 102  {1}, Sacrifice Goblin Cratermaker: Choose one ...
# 103  Whenever Goblin Locksmith attacks, creatures w...
# 104  Target creature you control deals damage equal...
# 105  Flying\r\nWhenever Hellkite Whelp attacks, it ...
# 106  This spell can't be countered.\r\nInescapable ...
# 107  Lava Coil deals 4 damage to target creature. I...
# 108  Mentor (Whenever this creature attacks, put a ...
# 109  Enchant creature\r\nEnchanted creature gets +2...
# 110  Target creature gets +1/+1 and gains haste unt...
# 111  Whenever Ornery Goblin blocks or becomes block...
# 112  Target opponent may have Risk Factor deal 4 da...
# 113  When Rubblebelt Boar enters the battlefield, t...
# 114  Whenever you cast a red spell, if Runaway Stea...
# 115  Whenever you cast an instant or sorcery spell,...
# 116  As long as it's your turn, creatures you contr...
# 117  Target creature gets +3/+0 and gains first str...
# 118  Haste\r\nSacrifice Torch Courier: Another targ...
# 119  Mentor (Whenever this creature attacks, put a ...
# 152  Flying\r\nMentor (Whenever this creature attac...
# 153  Beacon Bolt deals damage to target creature eq...
# 154  Whenever you cast an instant or sorcery spell ...
# 155  Mentor (Whenever this creature attacks, put a ...
# 156  You gain X life and draw X cards, where X is t...
# 157  When Centaur Peacemaker enters the battlefield...
# 158  Creatures you control gain indestructible. Tak...
# 160  Vigilance\r\nWhen Conclave Cavalier dies, crea...
# 161  {G}, {T}: Creatures you control gain trample u...
# 162  Flying\r\nCrackling Drake's power is equal to ...
# 164  Choose one or both —\r\n• Deafening Clarion de...
# 167  Whenever Emmara, Soul of the Accord becomes ta...
# 170  Whenever you cast an instant or sorcery spell,...
# 171  Garrison Sergeant has double strike as long as...
# 173  Instant and sorcery spells you cast cost {1} l...
# 175  Mentor (Whenever this creature attacks, put a ...
# 177  Draw two cards. Then you may discard a nonland...
# 178  Counter target spell. Ionize deals 2 damage to...
# 180  Untap all creatures you control. They gain hex...
# 181  Target creature deals damage to itself equal t...
# 182  When Knight of Autumn enters the battlefield, ...
# 184  {3}{U}, {T}: Draw a card.\r\n{X}{R}, {T}: Copy...
# 185  Whenever Ledev Champion attacks, you may tap a...
# 186  {5}{R}, {T}: Legion Guildmage deals 3 damage t...
# 187  Convoke (Your creatures can help cast this spe...
# 191  This spell can't be countered.\r\nFlying\r\nWh...
# 194  +1: Look at the top two cards of your library....
# 196  Convoke (Your creatures can help cast this spe...
# 197                                      Flying, haste
# 198  Tap target creature. Sonic Assault deals 2 dam...
# 199  When Sumala Woodshaper enters the battlefield,...
# 201  Vigilance\r\nWhenever Swathcutter Giant attack...
# 202                  Double strike, vigilance, trample
# 203  Haste\r\nMentor (Whenever this creature attack...
# 206  Whenever you cast an instant or sorcery spell,...
# 207  Other creatures you control get +1/+1.\r\nWhen...
# 208  Mentor (Whenever this creature attacks, put a ...
# 213  Flying\r\nWhenever you cast an instant or sorc...
# 214  Convoke (Your creatures can help cast this spe...
# 215  As long as it's your turn, Fresh-Faced Recruit...
# 216  Defender\r\nAs long as you've cast an instant ...
# 218                                          Vigilance
# 220  Put a +1/+1 counter on target creature. That c...
# 221  Create three 2/2 green and white Elf Knight cr...
# 226  Copy target instant or sorcery spell with conv...
# 227  Explosion deals X damage to any target. Target...
# 230  Search your library for a basic Forest or Plai...
# 231  Creatures you control get +2/+2 until end of t...
# 232      Target creature gets +2/+2 until end of turn.
# 233  Intervention deals 3 damage to any target and ...
# 234  Switch the power and toughness of each of up t...
# 235  Search your library for an instant card and/or...
# 236  Response deals 5 damage to target attacking or...
# 237  Creatures you control gain first strike and vi...
# 240  {T}: Add {R} or {W}.\r\n{R/W}{R/W}{R/W}{R/W}, ...
# 241  Chamber Sentry enters the battlefield with a +...
# 247  {T}: Add {U} or {R}.\r\n{U/R}{U/R}{U/R}{U/R}, ...
# 249  {T}: Add {G} or {W}.\r\n{G/W}{G/W}{G/W}{G/W}, ...
# 252  Boros Guildgate enters the battlefield tapped....
# 253  Boros Guildgate enters the battlefield tapped....
# 260  Izzet Guildgate enters the battlefield tapped....
# 261  Izzet Guildgate enters the battlefield tapped....
# 263  ({T}: Add {R} or {W}.)\r\nAs Sacred Foundry en...
# 264  Selesnya Guildgate enters the battlefield tapp...
# 265  Selesnya Guildgate enters the battlefield tapp...
# 266  ({T}: Add {U} or {R}.)\r\nAs Steam Vents enter...
# 267  ({T}: Add {G} or {W}.)\r\nAs Temple Garden ent...
# 269                                                NaN
# 272                                                NaN
# 274  +1: Draw a card.\r\n−2: Ral, Caller of Storms ...
# 276       Precision Bolt deals 3 damage to any target.
# 277  Trample (This creature can deal excess combat ...
#
#                                                 flavor                artist  \
# 0    "Watch carefully. The gap between death and vi...          Zoltan Boros
# 1    "Lately I've seen the biggest bounties of my c...          Randy Vargas
# 2    Selesnya guildmages do not sleep so the rest o...   Alexander Forssberg
# 3    "Oh, you fellas are going to love the lockup. ...  Victor Adame Minguez
# 4    "Reports of Gruul rioters in four districts. S...  Victor Adame Minguez
# 5                                                  NaN          Seb McKinnon
# 6    The Izzet mage knew she would neither get her ...        Jason A. Engle
# 7    "To wage war, secure peace within yourself."\r...             Sung Choi
# 8    There's no greater honor than joining your cho...           Joe Slucher
# 227  Guilds of Ravnica  0a9654bfc560c24eb89d94491ee9fa172df2a958 NaN
# 230  Guilds of Ravnica  1e9d128ad2af4dffb398be5b9a5ccd7a58b25bf5 NaN
# 231  Guilds of Ravnica  86829718902da8a35355190494e8125e08c3bb1e NaN
# 232  Guilds of Ravnica  9f47d20a3c73905078f82551eb86a7ef9fc58225 NaN
# 233  Guilds of Ravnica  bfb69b217c34efa1f3a010f8e7170510627ff653 NaN
# 234  Guilds of Ravnica  047b6af9fdfe2019a54fe15d062bb9f7f44ea565 NaN
# 235  Guilds of Ravnica  70b628ade616c80c66ae79f042ec5ddeee3668ff NaN
# 236  Guilds of Ravnica  88183bec42ea31ae69d12165268e27e80a270ab7 NaN
# 237  Guilds of Ravnica  443b0cebf885e12f7fc414db01f706c14d0ea637 NaN
# 240  Guilds of Ravnica  91571d8ca0ebf628f8bda42ec40703bd70a5999d NaN
# 241  Guilds of Ravnica  e067cc06ab7072e580a7b01730ae050d3ee4b981 NaN
# 247  Guilds of Ravnica  46c4066f67c8351f245bd91a4198ea7a6617e9ec NaN
# 249  Guilds of Ravnica  3819ebda2242f26ccdbe2640af552a7e49787db5 NaN
# 252  Guilds of Ravnica  282c89f7ee172ad0dbc45e15cb5e2436f177ad7d NaN
# 253  Guilds of Ravnica  b7c239a1c9a4a068edc61cef2382bed8f884a45a NaN
# 260  Guilds of Ravnica  0407219e7a5437bee0c8f4ca2b123c35d242c8cd NaN
# 261  Guilds of Ravnica  cb3c31c72c2cd254a6de27c900c7489774eae421 NaN
# 263  Guilds of Ravnica  39f85f6d4a24bf71f2b881a25fdf66fc13f82595 NaN
# 264  Guilds of Ravnica  58521eda75925266b6e2a5e55787a299e7a2e585 NaN
# 265  Guilds of Ravnica  e6f694301f7d98792504085d37e54fe7a636f228 NaN
# 266  Guilds of Ravnica  f678dfc7bebb992fcc4abc6274b523b28b8ab57c NaN
# 267  Guilds of Ravnica  22f8f319d6ca0f898957fd2fc31abd491f26cd62 NaN
# 269  Guilds of Ravnica  7fda130df48e37c3629e25f37956a27e0315864b NaN
# 272  Guilds of Ravnica  df6dcb416debce5c43db0f4fc747b513d1cd0f0f NaN
# 274  Guilds of Ravnica  cfd6eab668d29678262a4705f0a36f72bf715034 NaN
# 276  Guilds of Ravnica  e73dfcdff885f2c4c96015edaa2e0105a37b4414 NaN
# 277  Guilds of Ravnica  14319db65459d582ef44c9c230c2b5beda05b964 NaN

# %% [markdown]
# Is also possible to apply a filter over a filter.
#
# In this case is filtering the result of the cell above by cards with the word 'Izzet' in the name

# %%
list = compare.filterCardSetListBy(compare.cardSetList, compare.card.name,'Izzet')
compare.plotCardSetList(list)
# Out:
# Guilds of Ravnica
#                     name  multiverse_id  layout names  mana_cost  cmc  \
# 194   Ral, Izzet Viceroy         452945  normal   NaN  {3}{U}{R}    5
# 247         Izzet Locket         452988  normal   NaN        {3}    3
# 260  Izzet Guildgate (a)         453001  normal   NaN        NaN    0
# 261  Izzet Guildgate (b)         453002  normal   NaN        NaN    0
#
#               colors color_identity                          type  \
# 194  ['Blue', 'Red']     ['U', 'R']  Legendary Planeswalker — Ral
# 247              NaN     ['U', 'R']                      Artifact
# 260              NaN     ['U', 'R']                   Land — Gate
# 261              NaN     ['U', 'R']                   Land — Gate
#
#         supertypes  subtypes       rarity  \
# 194  ['Legendary']   ['Ral']  Mythic Rare
# 247            NaN       NaN       Common
# 260            NaN  ['Gate']       Common
# 261            NaN  ['Gate']       Common
#
#                                                   text  \
# 194  +1: Look at the top two cards of your library....
# 247  {T}: Add {U} or {R}.\r\n{U/R}{U/R}{U/R}{U/R}, ...
# 260  Izzet Guildgate enters the battlefield tapped....
# 261  Izzet Guildgate enters the battlefield tapped....
#
#                                                 flavor            artist  \
# 194                                                NaN     Kieran Yanner
# 247  "Remember to discharge your locket every seven...     Dmitry Burmak
# 260  Every laboratory buzzes with new experiments, ...  Kirsten Zirngibl
# 261  "Yesterday I didn't recognize my own guild. To...  Kirsten Zirngibl
#
#     number power  toughness  loyalty  variations watermark  border  \
# 194    195   NaN        NaN      5.0         NaN       NaN     NaN
# 247    238   NaN        NaN      NaN         NaN     Izzet     NaN
# 260    251   NaN        NaN      NaN         NaN     Izzet     NaN
# 261    252   NaN        NaN      NaN         NaN     Izzet     NaN
#
#      timeshifted  hand  life  reserved  release_date  \
# 194          NaN   NaN   NaN       NaN           NaN
# 247          NaN   NaN   NaN       NaN           NaN
# 260          NaN   NaN   NaN       NaN           NaN
# 261          NaN   NaN   NaN       NaN           NaN
#
#                                                starter  \
# 194  [{'text': "If you have only one card in your l...
# 247                                                NaN
# 260                                                NaN
# 261                                                NaN
#
#                                                rulings foreign_names  \
# 194  [{'name': 'Ral, Izzet-Statthalter', 'imageUrl'...       ['GRN']
# 247  [{'name': 'Izzet-Medaillon', 'imageUrl': 'http...       ['GRN']
# 260  [{'name': 'Izzet-Gildeneingang', 'imageUrl': '...       ['GRN']
# 261  [{'name': 'Izzet-Gildeneingang', 'imageUrl': '...       ['GRN']
#
#                                              printings  \
# 194  +1: Look at the top two cards of your library....
# 247  {T}: Add {U} or {R}.\r\n{U/R}{U/R}{U/R}{U/R}, ...
# 260  Izzet Guildgate enters the battlefield tapped....
# 261  Izzet Guildgate enters the battlefield tapped....
#
#                     original_text original_type  legalities  \
# 194  Legendary Planeswalker — Ral           NaN         NaN
# 247                      Artifact           NaN         NaN
# 260                   Land — Gate           NaN         NaN
# 261                   Land — Gate           NaN         NaN
#
#                                                 source image_url  \
# 194  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 247  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 260  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
# 261  http://gatherer.wizards.com/Handlers/Image.ash...       GRN
#
#                    set                                  set_name  id
# 194  Guilds of Ravnica  29e8caee7e56328bd4b18115a388cc5b7bf415f3 NaN
# 247  Guilds of Ravnica  46c4066f67c8351f245bd91a4198ea7a6617e9ec NaN
# 260  Guilds of Ravnica  0407219e7a5437bee0c8f4ca2b123c35d242c8cd NaN
# 261  Guilds of Ravnica  cb3c31c72c2cd254a6de27c900c7489774eae421 NaN
